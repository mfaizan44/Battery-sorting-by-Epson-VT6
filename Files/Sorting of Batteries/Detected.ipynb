# %%
import cv2
import numpy as np
import os
import glob

# Set the size of the pattern (7x7 for example)
pattern_size = (16, 11)

# Termination criteria for refining corner positions
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)

# Prepare object points based on the pattern size
objp = np.zeros((np.prod(pattern_size), 3), np.float32)
objp[:, :2] = np.mgrid[0:pattern_size[0], 0:pattern_size[1]].T.reshape(-1, 2)

# Arrays to store object points and image points
objpoints = []  # 3D points in real world space
imgpoints = []  # 2D points in image plane

# Image path for calibration images
image_path = r'C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern'

# Function to detect and save pattern from images
def detect_pattern(image_folder):
    images = glob.glob(os.path.join(image_folder, '*.jpg'))  # Load all images in the folder
    save_dir = os.path.join(image_folder, 'detected_patterns')  # Directory to save detected patterns
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    for idx, fname in enumerate(images):
        img = cv2.imread(fname)
        if img is None:
            print(f"Failed to load image {fname}")
            continue
        
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        
        # Detect the circles grid pattern
        ret, corners = cv2.findCirclesGrid(gray, pattern_size, cv2.CALIB_CB_SYMMETRIC_GRID)
        
        if ret:
            objpoints.append(objp)
            imgpoints.append(corners)
            
            # Draw and display the detected corners
            cv2.drawChessboardCorners(img, pattern_size, corners, ret)
            
            # Save the image with detected pattern
            save_image_path = os.path.join(save_dir, f"pattern_detected_{idx}.jpg")
            cv2.imwrite(save_image_path, img)
            print(f"Pattern detected and saved: {save_image_path}")
        else:
            print(f"Pattern not detected in {fname}")

    # Perform camera calibration if enough points are detected
    if len(objpoints) > 0 and len(imgpoints) > 0:
        ret, camera_matrix, dist_coeffs, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, gray.shape[::-1], None, None)
        
        # Save the calibration data
        np.savez(os.path.join(image_folder, 'calibration_data.npz'), mtx=camera_matrix, dist=dist_coeffs)
        print("Calibration successful. Data saved.")
    else:
        print("No patterns were detected. Calibration could not be performed.")

# Call the function to process the images
detect_pattern(image_path)
# Out:
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_0.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_1.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_2.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_3.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_4.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_5.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_6.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_7.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_8.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_9.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_10.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_11.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_12.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_13.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_14.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_15.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_16.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_17.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_18.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_19.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_20.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_21.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_22.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_23.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_24.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_25.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_26.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_27.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_28.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_29.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_30.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_31.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_32.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_33.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_34.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_35.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_36.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_37.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_38.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_39.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_40.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_41.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_42.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_43.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_44.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_45.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_46.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_47.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_48.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_49.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_50.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_51.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_52.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_53.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_54.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_55.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_56.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_57.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_58.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_59.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_60.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_61.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_62.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_63.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_64.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_65.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_66.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_67.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_68.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_69.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_70.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_71.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_72.jpg
# Pattern detected and saved: C:\Users\mfaiz\Desktop\PROJECT\Sorting of Batteries\Camera Caliberation\Pattern\detected_patterns\pattern_detected_73.jpg
# Calibration successful. Data saved.
