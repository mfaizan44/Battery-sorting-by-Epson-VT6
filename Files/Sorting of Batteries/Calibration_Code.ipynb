# %%
import cv2
import numpy as np
import os

# Define the dimensions of the dot grid
num_rows = 7
num_cols = 9
num_dots = num_rows * num_cols

def detect_dots(img):
    dot_centers = []

    # Convert image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Apply adaptive thresholding to enhance dot visibility
    _, binary = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    # Use morphological operations to remove small noise and to separate dots connected to objects
    kernel = np.ones((3, 3), np.uint8)
    morphed = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel, iterations=2)

    # Find contours in the morphed image
    contours, _ = cv2.findContours(morphed, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Filter contours by area to find the dots
    for contour in contours:
        area = cv2.contourArea(contour)
        if 50 < area < 500:  # Adjust these values based on your dot size
            M = cv2.moments(contour)
            if M["m00"] != 0:
                center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))
                dot_centers.append(center)

    return dot_centers

# Directory containing your dataset images
dataset_dir = 'C:/Users/mfaiz/Desktop/PROJECT/dataset_bat/train/images/'

# Output directory for storing detected dot centers or further processing
output_dir = 'C:/Users/mfaiz/Desktop/PROJECT/detected_dot_centers/'

# Ensure output directory exists, create if not
os.makedirs(output_dir, exist_ok=True)

# List to store all detected dot centers as numpy arrays
all_dot_centers = []

# Iterate through each image in the dataset directory
for filename in os.listdir(dataset_dir):
    if filename.endswith(".jpg") or filename.endswith(".jpeg") or filename.endswith(".png"):
        # Load image
        img_path = os.path.join(dataset_dir, filename)
        img = cv2.imread(img_path)

        if img is None:
            print(f"Error loading image: {img_path}")
            continue

        # Detect dots in the image
        detected_centers = detect_dots(img)

        # Convert detected centers to numpy array
        detected_centers_np = np.array(detected_centers)

        # Append detected dot centers to the list
        all_dot_centers.append(detected_centers_np)

        print(f"Detected dot centers saved for {filename}")

# Save all detected dot centers to a single .npz file
np.savez(os.path.join(output_dir, 'detected_dot_centers.npz'), *all_dot_centers)

print("Detection process completed.")
# Out:
# Detected dot centers saved for batteries (100).jpg
# Detected dot centers saved for batteries (101).jpg
# Detected dot centers saved for batteries (102).jpg
# Detected dot centers saved for batteries (103).jpg
# Detected dot centers saved for batteries (104).jpg
# Detected dot centers saved for batteries (105).jpg
# Detected dot centers saved for batteries (106).jpg
# Detected dot centers saved for batteries (107).jpg
# Detected dot centers saved for batteries (108).jpg
# Detected dot centers saved for batteries (109).jpg
# Detected dot centers saved for batteries (110).jpg
# Detected dot centers saved for batteries (111).jpg
# Detected dot centers saved for batteries (112).jpg
# Detected dot centers saved for batteries (113).jpg
# Detected dot centers saved for batteries (114).jpg
# Detected dot centers saved for batteries (115).jpg
# Detected dot centers saved for batteries (116).jpg
# Detected dot centers saved for batteries (117).jpg
# Detected dot centers saved for batteries (118).jpg
# Detected dot centers saved for batteries (119).jpg
# Detected dot centers saved for batteries (120).jpg
# Detected dot centers saved for batteries (121).jpg
# Detected dot centers saved for batteries (122).jpg
# Detected dot centers saved for batteries (123).jpg
# Detected dot centers saved for batteries (124).jpg
# Detected dot centers saved for batteries (125).jpg
# Detected dot centers saved for batteries (126).jpg
# Detected dot centers saved for batteries (127).jpg
# Detected dot centers saved for batteries (128).jpg
# Detected dot centers saved for batteries (129).jpg
# Detected dot centers saved for batteries (13).jpg
# Detected dot centers saved for batteries (130).jpg
# Detected dot centers saved for batteries (131).jpg
# Detected dot centers saved for batteries (132).jpg
# Detected dot centers saved for batteries (133).jpg
# Detected dot centers saved for batteries (134).jpg
# Detected dot centers saved for batteries (135).jpg
# Detected dot centers saved for batteries (136).jpg
# Detected dot centers saved for batteries (137).jpg
# Detected dot centers saved for batteries (138).jpg
# Detected dot centers saved for batteries (139).jpg
# Detected dot centers saved for batteries (140).jpg
# Detected dot centers saved for batteries (141).jpg
# Detected dot centers saved for batteries (142).jpg
# Detected dot centers saved for batteries (143).jpg
# Detected dot centers saved for batteries (144).jpg
# Detected dot centers saved for batteries (145).jpg
# Detected dot centers saved for batteries (146).jpg
# Detected dot centers saved for batteries (147).jpg
# Detected dot centers saved for batteries (148).jpg
# Detected dot centers saved for batteries (149).jpg
# Detected dot centers saved for batteries (150).jpg
# Detected dot centers saved for batteries (151).jpg
# Detected dot centers saved for batteries (152).jpg
# Detected dot centers saved for batteries (153).jpg
# Detected dot centers saved for batteries (154).jpg
# Detected dot centers saved for batteries (155).jpg
# Detected dot centers saved for batteries (156).jpg
# Detected dot centers saved for batteries (157).jpg
# Detected dot centers saved for batteries (158).jpg
# Detected dot centers saved for batteries (159).jpg
# Detected dot centers saved for batteries (160).jpg
# Detected dot centers saved for batteries (161).jpg
# Detected dot centers saved for batteries (162).jpg
# Detected dot centers saved for batteries (163).jpg
# Detected dot centers saved for batteries (164).jpg
# Detected dot centers saved for batteries (165).jpg
# Detected dot centers saved for batteries (166).jpg
# Detected dot centers saved for batteries (167).jpg
# Detected dot centers saved for batteries (168).jpg
# Detected dot centers saved for batteries (169).jpg
# Detected dot centers saved for batteries (170).jpg
# Detected dot centers saved for batteries (171).jpg
# Detected dot centers saved for batteries (172).jpg
# Detected dot centers saved for batteries (173).jpg
# Detected dot centers saved for batteries (174).jpg
# Detected dot centers saved for batteries (175).jpg
# Detected dot centers saved for batteries (176).jpg
# Detected dot centers saved for batteries (177).jpg
# Detected dot centers saved for batteries (178).jpg
# Detected dot centers saved for batteries (179).jpg
# Detected dot centers saved for batteries (180).jpg
# Detected dot centers saved for batteries (181).jpg
# Detected dot centers saved for batteries (182).jpg
# Detected dot centers saved for batteries (183).jpg
# Detected dot centers saved for batteries (184).jpg
# Detected dot centers saved for batteries (185).jpg
# Detected dot centers saved for batteries (186).jpg
# Detected dot centers saved for batteries (187).jpg
# Detected dot centers saved for batteries (188).jpg
# Detected dot centers saved for batteries (189).jpg
# Detected dot centers saved for batteries (190).jpg
# Detected dot centers saved for batteries (191).jpg
# Detected dot centers saved for batteries (192).jpg
# Detected dot centers saved for batteries (193).jpg
# Detected dot centers saved for batteries (194).jpg
# Detected dot centers saved for batteries (195).jpg
# Detected dot centers saved for batteries (196).jpg
# Detected dot centers saved for batteries (197).jpg
# Detected dot centers saved for batteries (198).jpg
# Detected dot centers saved for batteries (199).jpg
# Detected dot centers saved for batteries (200).jpg
# Detected dot centers saved for batteries (201).jpg
# Detected dot centers saved for batteries (202).jpg
# Detected dot centers saved for batteries (203).jpg
# Detected dot centers saved for batteries (204).jpg
# Detected dot centers saved for batteries (205).jpg
# Detected dot centers saved for batteries (206).jpg
# Detected dot centers saved for batteries (207).jpg
# Detected dot centers saved for batteries (208).jpg
# Detected dot centers saved for batteries (209).jpg
# Detected dot centers saved for batteries (21).jpg
# Detected dot centers saved for batteries (210).jpg
# Detected dot centers saved for batteries (211).jpg
# Detected dot centers saved for batteries (212).jpg
# Detected dot centers saved for batteries (213).jpg
# Detected dot centers saved for batteries (214).jpg
# Detected dot centers saved for batteries (215).jpg
# Detected dot centers saved for batteries (216).jpg
# Detected dot centers saved for batteries (217).jpg
# Detected dot centers saved for batteries (218).jpg
# Detected dot centers saved for batteries (219).jpg
# Detected dot centers saved for batteries (22).jpg
# Detected dot centers saved for batteries (220).jpg
# Detected dot centers saved for batteries (221).jpg
# Detected dot centers saved for batteries (222).jpg
# Detected dot centers saved for batteries (223).jpg
# Detected dot centers saved for batteries (224).jpg
# Detected dot centers saved for batteries (225).jpg
# Detected dot centers saved for batteries (226).jpg
# Detected dot centers saved for batteries (227).jpg
# Detected dot centers saved for batteries (228).jpg
# Detected dot centers saved for batteries (229).jpg
# Detected dot centers saved for batteries (23).jpg
# Detected dot centers saved for batteries (230).jpg
# Detected dot centers saved for batteries (231).jpg
# Detected dot centers saved for batteries (232).jpg
# Detected dot centers saved for batteries (233).jpg
# Detected dot centers saved for batteries (234).jpg
# Detected dot centers saved for batteries (235).jpg
# Detected dot centers saved for batteries (236).jpg
# Detected dot centers saved for batteries (237).jpg
# Detected dot centers saved for batteries (238).jpg
# Detected dot centers saved for batteries (239).jpg
# Detected dot centers saved for batteries (24).jpg
# Detected dot centers saved for batteries (244).jpg
# Detected dot centers saved for batteries (245).jpg
# Detected dot centers saved for batteries (246).jpg
# Detected dot centers saved for batteries (247).jpg
# Detected dot centers saved for batteries (248).jpg
# Detected dot centers saved for batteries (249).jpg
# Detected dot centers saved for batteries (25).jpg
# Detected dot centers saved for batteries (250).jpg
# Detected dot centers saved for batteries (251).jpg
# Detected dot centers saved for batteries (252).jpg
# Detected dot centers saved for batteries (253).jpg
# Detected dot centers saved for batteries (254).jpg
# Detected dot centers saved for batteries (255).jpg
# Detected dot centers saved for batteries (256).jpg
# Detected dot centers saved for batteries (257).jpg
# Detected dot centers saved for batteries (258).jpg
# Detected dot centers saved for batteries (259).jpg
# Detected dot centers saved for batteries (26).jpg
# Detected dot centers saved for batteries (260).jpg
# Detected dot centers saved for batteries (261).jpg
# Detected dot centers saved for batteries (262).jpg
# Detected dot centers saved for batteries (263).jpg
# Detected dot centers saved for batteries (264).jpg
# Detected dot centers saved for batteries (265).jpg
# Detected dot centers saved for batteries (266).jpg
# Detected dot centers saved for batteries (267).jpg
# Detected dot centers saved for batteries (268).jpg
# Detected dot centers saved for batteries (269).jpg
# Detected dot centers saved for batteries (27).jpg
# Detected dot centers saved for batteries (270).jpg
# Detected dot centers saved for batteries (271).jpg
# Detected dot centers saved for batteries (272).jpg
# Detected dot centers saved for batteries (273).jpg
# Detected dot centers saved for batteries (274).jpg
# Detected dot centers saved for batteries (275).jpg
# Detected dot centers saved for batteries (276).jpg
# Detected dot centers saved for batteries (277).jpg
# Detected dot centers saved for batteries (278).jpg
# Detected dot centers saved for batteries (279).jpg
# Detected dot centers saved for batteries (28).jpg
# Detected dot centers saved for batteries (280).jpg
# Detected dot centers saved for batteries (281).jpg
# Detected dot centers saved for batteries (282).jpg
# Detected dot centers saved for batteries (283).jpg
# Detected dot centers saved for batteries (284).jpg
# Detected dot centers saved for batteries (285).jpg
# Detected dot centers saved for batteries (286).jpg
# Detected dot centers saved for batteries (287).jpg
# Detected dot centers saved for batteries (288).jpg
# Detected dot centers saved for batteries (289).jpg
# Detected dot centers saved for batteries (29).jpg
# Detected dot centers saved for batteries (290).jpg
# Detected dot centers saved for batteries (291).jpg
# Detected dot centers saved for batteries (292).jpg
# Detected dot centers saved for batteries (293).jpg
# Detected dot centers saved for batteries (294).jpg
# Detected dot centers saved for batteries (295).jpg
# Detected dot centers saved for batteries (296).jpg
# Detected dot centers saved for batteries (297).jpg
# Detected dot centers saved for batteries (298).jpg
# Detected dot centers saved for batteries (299).jpg
# Detected dot centers saved for batteries (30).jpg
# Detected dot centers saved for batteries (300).jpg
# Detected dot centers saved for batteries (301).jpg
# Detected dot centers saved for batteries (302).jpg
# Detected dot centers saved for batteries (303).jpg
# Detected dot centers saved for batteries (304).jpg
# Detected dot centers saved for batteries (305).jpg
# Detected dot centers saved for batteries (306).jpg
# Detected dot centers saved for batteries (307).jpg
# Detected dot centers saved for batteries (308).jpg
# Detected dot centers saved for batteries (309).jpg
# Detected dot centers saved for batteries (31).jpg
# Detected dot centers saved for batteries (310).jpg
# Detected dot centers saved for batteries (311).jpg
# Detected dot centers saved for batteries (312).jpg
# Detected dot centers saved for batteries (313).jpg
# Detected dot centers saved for batteries (314).jpg
# Detected dot centers saved for batteries (315).jpg
# Detected dot centers saved for batteries (316).jpg
# Detected dot centers saved for batteries (317).jpg
# Detected dot centers saved for batteries (318).jpg
# Detected dot centers saved for batteries (319).jpg
# Detected dot centers saved for batteries (32).jpg
# Detected dot centers saved for batteries (320).jpg
# Detected dot centers saved for batteries (321).jpg
# Detected dot centers saved for batteries (322).jpg
# Detected dot centers saved for batteries (323).jpg
# Detected dot centers saved for batteries (324).jpg
# Detected dot centers saved for batteries (325).jpg
# Detected dot centers saved for batteries (326).jpg
# Detected dot centers saved for batteries (327).jpg
# Detected dot centers saved for batteries (328).jpg
# Detected dot centers saved for batteries (329).jpg
# Detected dot centers saved for batteries (33).jpg
# Detected dot centers saved for batteries (330).jpg
# Detected dot centers saved for batteries (331).jpg
# Detected dot centers saved for batteries (332).jpg
# Detected dot centers saved for batteries (333).jpg
# Detected dot centers saved for batteries (334).jpg
# Detected dot centers saved for batteries (338).jpg
# Detected dot centers saved for batteries (339).jpg
# Detected dot centers saved for batteries (34).jpg
# Detected dot centers saved for batteries (340).jpg
# Detected dot centers saved for batteries (341).jpg
# Detected dot centers saved for batteries (342).jpg
# Detected dot centers saved for batteries (343).jpg
# Detected dot centers saved for batteries (344).jpg
# Detected dot centers saved for batteries (345).jpg
# Detected dot centers saved for batteries (346).jpg
# Detected dot centers saved for batteries (347).jpg
# Detected dot centers saved for batteries (348).jpg
# Detected dot centers saved for batteries (349).jpg
# Detected dot centers saved for batteries (35).jpg
# Detected dot centers saved for batteries (350).jpg
# Detected dot centers saved for batteries (351).jpg
# Detected dot centers saved for batteries (352).jpg
# Detected dot centers saved for batteries (353).jpg
# Detected dot centers saved for batteries (354).jpg
# Detected dot centers saved for batteries (355).jpg
# Detected dot centers saved for batteries (356).jpg
# Detected dot centers saved for batteries (36).jpg
# Detected dot centers saved for batteries (363).jpg
# Detected dot centers saved for batteries (364).jpg
# Detected dot centers saved for batteries (365).jpg
# Detected dot centers saved for batteries (366).jpg
# Detected dot centers saved for batteries (367).jpg
# Detected dot centers saved for batteries (368).jpg
# Detected dot centers saved for batteries (369).jpg
# Detected dot centers saved for batteries (37).jpg
# Detected dot centers saved for batteries (370).jpg
# Detected dot centers saved for batteries (371).jpg
# Detected dot centers saved for batteries (372).jpg
# Detected dot centers saved for batteries (373).jpg
# Detected dot centers saved for batteries (374).jpg
# Detected dot centers saved for batteries (375).jpg
# Detected dot centers saved for batteries (376).jpg
# Detected dot centers saved for batteries (377).jpg
# Detected dot centers saved for batteries (378).jpg
# Detected dot centers saved for batteries (379).jpg
# Detected dot centers saved for batteries (38).jpg
# Detected dot centers saved for batteries (380).jpg
# Detected dot centers saved for batteries (381).jpg
# Detected dot centers saved for batteries (382).jpg
# Detected dot centers saved for batteries (383).jpg
# Detected dot centers saved for batteries (384).jpg
# Detected dot centers saved for batteries (385).jpg
# Detected dot centers saved for batteries (386).jpg
# Detected dot centers saved for batteries (387).jpg
# Detected dot centers saved for batteries (388).jpg
# Detected dot centers saved for batteries (389).jpg
# Detected dot centers saved for batteries (39).jpg
# Detected dot centers saved for batteries (390).jpg
# Detected dot centers saved for batteries (391).jpg
# Detected dot centers saved for batteries (392).jpg
# Detected dot centers saved for batteries (393).jpg
# Detected dot centers saved for batteries (394).jpg
# Detected dot centers saved for batteries (395).jpg
# Detected dot centers saved for batteries (396).jpg
# Detected dot centers saved for batteries (397).jpg
# Detected dot centers saved for batteries (398).jpg
# Detected dot centers saved for batteries (399).jpg
# Detected dot centers saved for batteries (40).jpg
# Detected dot centers saved for batteries (400).jpg
# Detected dot centers saved for batteries (401).jpg
# Detected dot centers saved for batteries (402).jpg
# Detected dot centers saved for batteries (403).jpg
# Detected dot centers saved for batteries (404).jpg
# Detected dot centers saved for batteries (405).jpg
# Detected dot centers saved for batteries (406).jpg
# Detected dot centers saved for batteries (407).jpg
# Detected dot centers saved for batteries (408).jpg
# Detected dot centers saved for batteries (409).jpg
# Detected dot centers saved for batteries (41).jpg
# Detected dot centers saved for batteries (410).jpg
# Detected dot centers saved for batteries (411).jpg
# Detected dot centers saved for batteries (412).jpg
# Detected dot centers saved for batteries (413).jpg
# Detected dot centers saved for batteries (414).jpg
# Detected dot centers saved for batteries (415).jpg
# Detected dot centers saved for batteries (416).jpg
# Detected dot centers saved for batteries (417).jpg
# Detected dot centers saved for batteries (418).jpg
# Detected dot centers saved for batteries (419).jpg
# Detected dot centers saved for batteries (42).jpg
# Detected dot centers saved for batteries (420).jpg
# Detected dot centers saved for batteries (421).jpg
# Detected dot centers saved for batteries (422).jpg
# Detected dot centers saved for batteries (423).jpg
# Detected dot centers saved for batteries (424).jpg
# Detected dot centers saved for batteries (425).jpg
# Detected dot centers saved for batteries (426).jpg
# Detected dot centers saved for batteries (427).jpg
# Detected dot centers saved for batteries (428).jpg
# Detected dot centers saved for batteries (429).jpg
# Detected dot centers saved for batteries (43).jpg
# Detected dot centers saved for batteries (430).jpg
# Detected dot centers saved for batteries (431).jpg
# Detected dot centers saved for batteries (432).jpg
# Detected dot centers saved for batteries (433).jpg
# Detected dot centers saved for batteries (434).jpg
# Detected dot centers saved for batteries (435).jpg
# Detected dot centers saved for batteries (436).jpg
# Detected dot centers saved for batteries (437).jpg
# Detected dot centers saved for batteries (438).jpg
# Detected dot centers saved for batteries (439).jpg
# Detected dot centers saved for batteries (44).jpg
# Detected dot centers saved for batteries (440).jpg
# Detected dot centers saved for batteries (441).jpg
# Detected dot centers saved for batteries (442).jpg
# Detected dot centers saved for batteries (443).jpg
# Detected dot centers saved for batteries (444).jpg
# Detected dot centers saved for batteries (445).jpg
# Detected dot centers saved for batteries (446).jpg
# Detected dot centers saved for batteries (447).jpg
# Detected dot centers saved for batteries (448).jpg
# Detected dot centers saved for batteries (449).jpg
# Detected dot centers saved for batteries (45).jpg
# Detected dot centers saved for batteries (450).jpg
# Detected dot centers saved for batteries (451).jpg
# Detected dot centers saved for batteries (452).jpg
# Detected dot centers saved for batteries (453).jpg
# Detected dot centers saved for batteries (454).jpg
# Detected dot centers saved for batteries (455).jpg
# Detected dot centers saved for batteries (456).jpg
# Detected dot centers saved for batteries (457).jpg
# Detected dot centers saved for batteries (458).jpg
# Detected dot centers saved for batteries (459).jpg
# Detected dot centers saved for batteries (46).jpg
# Detected dot centers saved for batteries (460).jpg
# Detected dot centers saved for batteries (461).jpg
# Detected dot centers saved for batteries (462).jpg
# Detected dot centers saved for batteries (463).jpg
# Detected dot centers saved for batteries (464).jpg
# Detected dot centers saved for batteries (465).jpg
# Detected dot centers saved for batteries (466).jpg
# Detected dot centers saved for batteries (467).jpg
# Detected dot centers saved for batteries (468).jpg
# Detected dot centers saved for batteries (469).jpg
# Detected dot centers saved for batteries (47).jpg
# Detected dot centers saved for batteries (470).jpg
# Detected dot centers saved for batteries (471).jpg
# Detected dot centers saved for batteries (472).jpg
# Detected dot centers saved for batteries (473).jpg
# Detected dot centers saved for batteries (474).jpg
# Detected dot centers saved for batteries (475).jpg
# Detected dot centers saved for batteries (476).jpg
# Detected dot centers saved for batteries (477).jpg
# Detected dot centers saved for batteries (478).jpg
# Detected dot centers saved for batteries (479).jpg
# Detected dot centers saved for batteries (48).jpg
# Detected dot centers saved for batteries (480).jpg
# Detected dot centers saved for batteries (481).jpg
# Detected dot centers saved for batteries (482).jpg
# Detected dot centers saved for batteries (483).jpg
# Detected dot centers saved for batteries (484).jpg
# Detected dot centers saved for batteries (485).jpg
# Detected dot centers saved for batteries (486).jpg
# Detected dot centers saved for batteries (487).jpg
# Detected dot centers saved for batteries (488).jpg
# Detected dot centers saved for batteries (489).jpg
# Detected dot centers saved for batteries (49).jpg
# Detected dot centers saved for batteries (490).jpg
# Detected dot centers saved for batteries (491).jpg
# Detected dot centers saved for batteries (492).jpg
# Detected dot centers saved for batteries (493).jpg
# Detected dot centers saved for batteries (494).jpg
# Detected dot centers saved for batteries (495).jpg
# Detected dot centers saved for batteries (496).jpg
# Detected dot centers saved for batteries (497).jpg
# Detected dot centers saved for batteries (498).jpg
# Detected dot centers saved for batteries (499).jpg
# Detected dot centers saved for batteries (50).jpg
# Detected dot centers saved for batteries (500).jpg
# Detected dot centers saved for batteries (501).jpg
# Detected dot centers saved for batteries (502).jpg
# Detected dot centers saved for batteries (51).jpg
# Detected dot centers saved for batteries (510).jpg
# Detected dot centers saved for batteries (511).jpg
# Detected dot centers saved for batteries (512).jpg
# Detected dot centers saved for batteries (513).jpg
# Detected dot centers saved for batteries (514).jpg
# Detected dot centers saved for batteries (515).jpg
# Detected dot centers saved for batteries (516).jpg
# Detected dot centers saved for batteries (517).jpg
# Detected dot centers saved for batteries (518).jpg
# Detected dot centers saved for batteries (519).jpg
# Detected dot centers saved for batteries (52).jpg
# Detected dot centers saved for batteries (520).jpg
# Detected dot centers saved for batteries (521).jpg
# Detected dot centers saved for batteries (522).jpg
# Detected dot centers saved for batteries (523).jpg
# Detected dot centers saved for batteries (524).jpg
# Detected dot centers saved for batteries (525).jpg
# Detected dot centers saved for batteries (526).jpg
# Detected dot centers saved for batteries (527).jpg
# Detected dot centers saved for batteries (528).jpg
# Detected dot centers saved for batteries (529).jpg
# Detected dot centers saved for batteries (53).jpg
# Detected dot centers saved for batteries (530).jpg
# Detected dot centers saved for batteries (531).jpg
# Detected dot centers saved for batteries (532).jpg
# Detected dot centers saved for batteries (533).jpg
# Detected dot centers saved for batteries (534).jpg
# Detected dot centers saved for batteries (535).jpg
# Detected dot centers saved for batteries (536).jpg
# Detected dot centers saved for batteries (537).jpg
# Detected dot centers saved for batteries (538).jpg
# Detected dot centers saved for batteries (539).jpg
# Detected dot centers saved for batteries (54).jpg
# Detected dot centers saved for batteries (540).jpg
# Detected dot centers saved for batteries (541).jpg
# Detected dot centers saved for batteries (542).jpg
# Detected dot centers saved for batteries (543).jpg
# Detected dot centers saved for batteries (544).jpg
# Detected dot centers saved for batteries (545).jpg
# Detected dot centers saved for batteries (546).jpg
# Detected dot centers saved for batteries (547).jpg
# Detected dot centers saved for batteries (548).jpg
# Detected dot centers saved for batteries (549).jpg
# Detected dot centers saved for batteries (55).jpg
# Detected dot centers saved for batteries (550).jpg
# Detected dot centers saved for batteries (551).jpg
# Detected dot centers saved for batteries (552).jpg
# Detected dot centers saved for batteries (553).jpg
# Detected dot centers saved for batteries (554).jpg
# Detected dot centers saved for batteries (555).jpg
# Detected dot centers saved for batteries (556).jpg
# Detected dot centers saved for batteries (557).jpg
# Detected dot centers saved for batteries (558).jpg
# Detected dot centers saved for batteries (559).jpg
# Detected dot centers saved for batteries (56).jpg
# Detected dot centers saved for batteries (560).jpg
# Detected dot centers saved for batteries (561).jpg
# Detected dot centers saved for batteries (562).jpg
# Detected dot centers saved for batteries (563).jpg
# Detected dot centers saved for batteries (564).jpg
# Detected dot centers saved for batteries (565).jpg
# Detected dot centers saved for batteries (566).jpg
# Detected dot centers saved for batteries (57).jpg
# Detected dot centers saved for batteries (571).jpg
# Detected dot centers saved for batteries (572).jpg
# Detected dot centers saved for batteries (573).jpg
# Detected dot centers saved for batteries (574).jpg
# Detected dot centers saved for batteries (575).jpg
# Detected dot centers saved for batteries (576).jpg
# Detected dot centers saved for batteries (577).jpg
# Detected dot centers saved for batteries (578).jpg
# Detected dot centers saved for batteries (579).jpg
# Detected dot centers saved for batteries (58).jpg
# Detected dot centers saved for batteries (580).jpg
# Detected dot centers saved for batteries (581).jpg
# Detected dot centers saved for batteries (582).jpg
# Detected dot centers saved for batteries (583).jpg
# Detected dot centers saved for batteries (584).jpg
# Detected dot centers saved for batteries (585).jpg
# Detected dot centers saved for batteries (586).jpg
# Detected dot centers saved for batteries (587).jpg
# Detected dot centers saved for batteries (59).jpg
# Detected dot centers saved for batteries (60).jpg
# Detected dot centers saved for batteries (61).jpg
# Detected dot centers saved for batteries (62).jpg
# Detected dot centers saved for batteries (63).jpg
# Detected dot centers saved for batteries (64).jpg
# Detected dot centers saved for batteries (65).jpg
# Detected dot centers saved for batteries (66).jpg
# Detected dot centers saved for batteries (67).jpg
# Detected dot centers saved for batteries (68).jpg
# Detected dot centers saved for batteries (69).jpg
# Detected dot centers saved for batteries (70).jpg
# Detected dot centers saved for batteries (71).jpg
# Detected dot centers saved for batteries (72).jpg
# Detected dot centers saved for batteries (73).jpg
# Detected dot centers saved for batteries (74).jpg
# Detected dot centers saved for batteries (75).jpg
# Detected dot centers saved for batteries (76).jpg
# Detected dot centers saved for batteries (77).jpg
# Detected dot centers saved for batteries (78).jpg
# Detected dot centers saved for batteries (79).jpg
# Detected dot centers saved for batteries (80).jpg
# Detected dot centers saved for batteries (81).jpg
# Detected dot centers saved for batteries (82).jpg
# Detected dot centers saved for batteries (83).jpg
# Detected dot centers saved for batteries (84).jpg
# Detected dot centers saved for batteries (85).jpg
# Detected dot centers saved for batteries (86).jpg
# Detected dot centers saved for batteries (87).jpg
# Detected dot centers saved for batteries (88).jpg
# Detected dot centers saved for batteries (89).jpg
# Detected dot centers saved for batteries (90).jpg
# Detected dot centers saved for batteries (91).jpg
# Detected dot centers saved for batteries (92).jpg
# Detected dot centers saved for batteries (93).jpg
# Detected dot centers saved for batteries (94).jpg
# Detected dot centers saved for batteries (95).jpg
# Detected dot centers saved for batteries (96).jpg
# Detected dot centers saved for batteries (97).jpg
# Detected dot centers saved for batteries (98).jpg
# Detected dot centers saved for batteries (99).jpg
# Detected dot centers saved for battery (1).jpg
# Detected dot centers saved for battery (10).jpg
# Detected dot centers saved for battery (100).jpg
# Detected dot centers saved for battery (101).jpg
# Detected dot centers saved for battery (102).jpg
# Detected dot centers saved for battery (103).jpg
# Detected dot centers saved for battery (104).jpg
# Detected dot centers saved for battery (105).jpg
# Detected dot centers saved for battery (106).jpg
# Detected dot centers saved for battery (107).jpg
# Detected dot centers saved for battery (108).jpg
# Detected dot centers saved for battery (109).jpg
# Detected dot centers saved for battery (11).jpg
# Detected dot centers saved for battery (110).jpg
# Detected dot centers saved for battery (111).jpg
# Detected dot centers saved for battery (112).jpg
# Detected dot centers saved for battery (113).jpg
# Detected dot centers saved for battery (114).jpg
# Detected dot centers saved for battery (115).jpg
# Detected dot centers saved for battery (116).jpg
# Detected dot centers saved for battery (117).jpg
# Detected dot centers saved for battery (118).jpg
# Detected dot centers saved for battery (119).jpg
# Detected dot centers saved for battery (12).jpg
# Detected dot centers saved for battery (120).jpg
# Detected dot centers saved for battery (121).jpg
# Detected dot centers saved for battery (122).jpg
# Detected dot centers saved for battery (123).jpg
# Detected dot centers saved for battery (124).jpg
# Detected dot centers saved for battery (125).jpg
# Detected dot centers saved for battery (126).jpg
# Detected dot centers saved for battery (127).jpg
# Detected dot centers saved for battery (128).jpg
# Detected dot centers saved for battery (129).jpg
# Detected dot centers saved for battery (13).jpg
# Detected dot centers saved for battery (130).jpg
# Detected dot centers saved for battery (131).jpg
# Detected dot centers saved for battery (132).jpg
# Detected dot centers saved for battery (133).jpg
# Detected dot centers saved for battery (134).jpg
# Detected dot centers saved for battery (135).jpg
# Detected dot centers saved for battery (14).jpg
# Detected dot centers saved for battery (15).jpg
# Detected dot centers saved for battery (16).jpg
# Detected dot centers saved for battery (165).jpg
# Detected dot centers saved for battery (166).jpg
# Detected dot centers saved for battery (167).jpg
# Detected dot centers saved for battery (168).jpg
# Detected dot centers saved for battery (169).jpg
# Detected dot centers saved for battery (17).jpg
# Detected dot centers saved for battery (170).jpg
# Detected dot centers saved for battery (171).jpg
# Detected dot centers saved for battery (172).jpg
# Detected dot centers saved for battery (173).jpg
# Detected dot centers saved for battery (174).jpg
# Detected dot centers saved for battery (175).jpg
# Detected dot centers saved for battery (176).jpg
# Detected dot centers saved for battery (177).jpg
# Detected dot centers saved for battery (178).jpg
# Detected dot centers saved for battery (179).jpg
# Detected dot centers saved for battery (18).jpg
# Detected dot centers saved for battery (180).jpg
# Detected dot centers saved for battery (181).jpg
# Detected dot centers saved for battery (182).jpg
# Detected dot centers saved for battery (183).jpg
# Detected dot centers saved for battery (184).jpg
# Detected dot centers saved for battery (185).jpg
# Detected dot centers saved for battery (186).jpg
# Detected dot centers saved for battery (187).jpg
# Detected dot centers saved for battery (188).jpg
# Detected dot centers saved for battery (189).jpg
# Detected dot centers saved for battery (19).jpg
# Detected dot centers saved for battery (190).jpg
# Detected dot centers saved for battery (191).jpg
# Detected dot centers saved for battery (192).jpg
# Detected dot centers saved for battery (193).jpg
# Detected dot centers saved for battery (194).jpg
# Detected dot centers saved for battery (195).jpg
# Detected dot centers saved for battery (196).jpg
# Detected dot centers saved for battery (197).jpg
# Detected dot centers saved for battery (198).jpg
# Detected dot centers saved for battery (199).jpg
# Detected dot centers saved for battery (2).jpg
# Detected dot centers saved for battery (20).jpg
# Detected dot centers saved for battery (200).jpg
# Detected dot centers saved for battery (201).jpg
# Detected dot centers saved for battery (202).jpg
# Detected dot centers saved for battery (203).jpg
# Detected dot centers saved for battery (204).jpg
# Detected dot centers saved for battery (205).jpg
# Detected dot centers saved for battery (206).jpg
# Detected dot centers saved for battery (207).jpg
# Detected dot centers saved for battery (208).jpg
# Detected dot centers saved for battery (209).jpg
# Detected dot centers saved for battery (210).jpg
# Detected dot centers saved for battery (211).jpg
# Detected dot centers saved for battery (212).jpg
# Detected dot centers saved for battery (213).jpg
# Detected dot centers saved for battery (214).jpg
# Detected dot centers saved for battery (215).jpg
# Detected dot centers saved for battery (216).jpg
# Detected dot centers saved for battery (217).jpg
# Detected dot centers saved for battery (218).jpg
# Detected dot centers saved for battery (219).jpg
# Detected dot centers saved for battery (220).jpg
# Detected dot centers saved for battery (221).jpg
# Detected dot centers saved for battery (222).jpg
# Detected dot centers saved for battery (223).jpg
# Detected dot centers saved for battery (224).jpg
# Detected dot centers saved for battery (225).jpg
# Detected dot centers saved for battery (226).jpg
# Detected dot centers saved for battery (227).jpg
# Detected dot centers saved for battery (228).jpg
# Detected dot centers saved for battery (229).jpg
# Detected dot centers saved for battery (230).jpg
# Detected dot centers saved for battery (231).jpg
# Detected dot centers saved for battery (232).jpg
# Detected dot centers saved for battery (233).jpg
# Detected dot centers saved for battery (234).jpg
# Detected dot centers saved for battery (235).jpg
# Detected dot centers saved for battery (236).jpg
# Detected dot centers saved for battery (237).jpg
# Detected dot centers saved for battery (238).jpg
# Detected dot centers saved for battery (239).jpg
# Detected dot centers saved for battery (240).jpg
# Detected dot centers saved for battery (241).jpg
# Detected dot centers saved for battery (242).jpg
# Detected dot centers saved for battery (243).jpg
# Detected dot centers saved for battery (244).jpg
# Detected dot centers saved for battery (245).jpg
# Detected dot centers saved for battery (246).jpg
# Detected dot centers saved for battery (247).jpg
# Detected dot centers saved for battery (248).jpg
# Detected dot centers saved for battery (249).jpg
# Detected dot centers saved for battery (250).jpg
# Detected dot centers saved for battery (251).jpg
# Detected dot centers saved for battery (252).jpg
# Detected dot centers saved for battery (253).jpg
# Detected dot centers saved for battery (254).jpg
# Detected dot centers saved for battery (255).jpg
# Detected dot centers saved for battery (256).jpg
# Detected dot centers saved for battery (257).jpg
# Detected dot centers saved for battery (258).jpg
# Detected dot centers saved for battery (259).jpg
# Detected dot centers saved for battery (26).jpg
# Detected dot centers saved for battery (260).jpg
# Detected dot centers saved for battery (261).jpg
# Detected dot centers saved for battery (262).jpg
# Detected dot centers saved for battery (268).jpg
# Detected dot centers saved for battery (269).jpg
# Detected dot centers saved for battery (27).jpg
# Detected dot centers saved for battery (270).jpg
# Detected dot centers saved for battery (271).jpg
# Detected dot centers saved for battery (272).jpg
# Detected dot centers saved for battery (273).jpg
# Detected dot centers saved for battery (274).jpg
# Detected dot centers saved for battery (275).jpg
# Detected dot centers saved for battery (276).jpg
# Detected dot centers saved for battery (277).jpg
# Detected dot centers saved for battery (278).jpg
# Detected dot centers saved for battery (279).jpg
# Detected dot centers saved for battery (28).jpg
# Detected dot centers saved for battery (280).jpg
# Detected dot centers saved for battery (281).jpg
# Detected dot centers saved for battery (282).jpg
# Detected dot centers saved for battery (283).jpg
# Detected dot centers saved for battery (284).jpg
# Detected dot centers saved for battery (285).jpg
# Detected dot centers saved for battery (286).jpg
# Detected dot centers saved for battery (287).jpg
# Detected dot centers saved for battery (288).jpg
# Detected dot centers saved for battery (289).jpg
# Detected dot centers saved for battery (29).jpg
# Detected dot centers saved for battery (290).jpg
# Detected dot centers saved for battery (291).jpg
# Detected dot centers saved for battery (292).jpg
# Detected dot centers saved for battery (293).jpg
# Detected dot centers saved for battery (294).jpg
# Detected dot centers saved for battery (295).jpg
# Detected dot centers saved for battery (296).jpg
# Detected dot centers saved for battery (297).jpg
# Detected dot centers saved for battery (298).jpg
# Detected dot centers saved for battery (299).jpg
# Detected dot centers saved for battery (3).jpg
# Detected dot centers saved for battery (30).jpg
# Detected dot centers saved for battery (300).jpg
# Detected dot centers saved for battery (301).jpg
# Detected dot centers saved for battery (302).jpg
# Detected dot centers saved for battery (303).jpg
# Detected dot centers saved for battery (304).jpg
# Detected dot centers saved for battery (305).jpg
# Detected dot centers saved for battery (306).jpg
# Detected dot centers saved for battery (307).jpg
# Detected dot centers saved for battery (308).jpg
# Detected dot centers saved for battery (309).jpg
# Detected dot centers saved for battery (31).jpg
# Detected dot centers saved for battery (310).jpg
# Detected dot centers saved for battery (311).jpg
# Detected dot centers saved for battery (312).jpg
# Detected dot centers saved for battery (313).jpg
# Detected dot centers saved for battery (314).jpg
# Detected dot centers saved for battery (315).jpg
# Detected dot centers saved for battery (316).jpg
# Detected dot centers saved for battery (317).jpg
# Detected dot centers saved for battery (318).jpg
# Detected dot centers saved for battery (319).jpg
# Detected dot centers saved for battery (32).jpg
# Detected dot centers saved for battery (320).jpg
# Detected dot centers saved for battery (321).jpg
# Detected dot centers saved for battery (322).jpg
# Detected dot centers saved for battery (323).jpg
# Detected dot centers saved for battery (324).jpg
# Detected dot centers saved for battery (325).jpg
# Detected dot centers saved for battery (326).jpg
# Detected dot centers saved for battery (327).jpg
# Detected dot centers saved for battery (328).jpg
# Detected dot centers saved for battery (329).jpg
# Detected dot centers saved for battery (33).jpg
# Detected dot centers saved for battery (330).jpg
# Detected dot centers saved for battery (331).jpg
# Detected dot centers saved for battery (332).jpg
# Detected dot centers saved for battery (333).jpg
# Detected dot centers saved for battery (334).jpg
# Detected dot centers saved for battery (335).jpg
# Detected dot centers saved for battery (336).jpg
# Detected dot centers saved for battery (337).jpg
# Detected dot centers saved for battery (338).jpg
# Detected dot centers saved for battery (339).jpg
# Detected dot centers saved for battery (34).jpg
# Detected dot centers saved for battery (340).jpg
# Detected dot centers saved for battery (341).jpg
# Detected dot centers saved for battery (342).jpg
# Detected dot centers saved for battery (343).jpg
# Detected dot centers saved for battery (344).jpg
# Detected dot centers saved for battery (345).jpg
# Detected dot centers saved for battery (346).jpg
# Detected dot centers saved for battery (347).jpg
# Detected dot centers saved for battery (348).jpg
# Detected dot centers saved for battery (349).jpg
# Detected dot centers saved for battery (35).jpg
# Detected dot centers saved for battery (350).jpg
# Detected dot centers saved for battery (351).jpg
# Detected dot centers saved for battery (352).jpg
# Detected dot centers saved for battery (353).jpg
# Detected dot centers saved for battery (354).jpg
# Detected dot centers saved for battery (355).jpg
# Detected dot centers saved for battery (356).jpg
# Detected dot centers saved for battery (357).jpg
# Detected dot centers saved for battery (358).jpg
# Detected dot centers saved for battery (359).jpg
# Detected dot centers saved for battery (36).jpg
# Detected dot centers saved for battery (360).jpg
# Detected dot centers saved for battery (361).jpg
# Detected dot centers saved for battery (362).jpg
# Detected dot centers saved for battery (363).jpg
# Detected dot centers saved for battery (364).jpg
# Detected dot centers saved for battery (365).jpg
# Detected dot centers saved for battery (366).jpg
# Detected dot centers saved for battery (367).jpg
# Detected dot centers saved for battery (368).jpg
# Detected dot centers saved for battery (37).jpg
# Detected dot centers saved for battery (372).jpg
# Detected dot centers saved for battery (373).jpg
# Detected dot centers saved for battery (374).jpg
# Detected dot centers saved for battery (375).jpg
# Detected dot centers saved for battery (376).jpg
# Detected dot centers saved for battery (377).jpg
# Detected dot centers saved for battery (378).jpg
# Detected dot centers saved for battery (379).jpg
# Detected dot centers saved for battery (38).jpg
# Detected dot centers saved for battery (380).jpg
# Detected dot centers saved for battery (381).jpg
# Detected dot centers saved for battery (382).jpg
# Detected dot centers saved for battery (383).jpg
# Detected dot centers saved for battery (384).jpg
# Detected dot centers saved for battery (385).jpg
# Detected dot centers saved for battery (386).jpg
# Detected dot centers saved for battery (387).jpg
# Detected dot centers saved for battery (388).jpg
# Detected dot centers saved for battery (389).jpg
# Detected dot centers saved for battery (39).jpg
# Detected dot centers saved for battery (390).jpg
# Detected dot centers saved for battery (391).jpg
# Detected dot centers saved for battery (392).jpg
# Detected dot centers saved for battery (393).jpg
# Detected dot centers saved for battery (394).jpg
# Detected dot centers saved for battery (395).jpg
# Detected dot centers saved for battery (396).jpg
# Detected dot centers saved for battery (397).jpg
# Detected dot centers saved for battery (398).jpg
# Detected dot centers saved for battery (399).jpg
# Detected dot centers saved for battery (4).jpg
# Detected dot centers saved for battery (40).jpg
# Detected dot centers saved for battery (400).jpg
# Detected dot centers saved for battery (401).jpg
# Detected dot centers saved for battery (402).jpg
# Detected dot centers saved for battery (403).jpg
# Detected dot centers saved for battery (404).jpg
# Detected dot centers saved for battery (405).jpg
# Detected dot centers saved for battery (406).jpg
# Detected dot centers saved for battery (407).jpg
# Detected dot centers saved for battery (408).jpg
# Detected dot centers saved for battery (409).jpg
# Detected dot centers saved for battery (41).jpg
# Detected dot centers saved for battery (410).jpg
# Detected dot centers saved for battery (411).jpg
# Detected dot centers saved for battery (412).jpg
# Detected dot centers saved for battery (413).jpg
# Detected dot centers saved for battery (414).jpg
# Detected dot centers saved for battery (415).jpg
# Detected dot centers saved for battery (416).jpg
# Detected dot centers saved for battery (417).jpg
# Detected dot centers saved for battery (418).jpg
# Detected dot centers saved for battery (42).jpg
# Detected dot centers saved for battery (420).jpg
# Detected dot centers saved for battery (421).jpg
# Detected dot centers saved for battery (422).jpg
# Detected dot centers saved for battery (423).jpg
# Detected dot centers saved for battery (424).jpg
# Detected dot centers saved for battery (425).jpg
# Detected dot centers saved for battery (426).jpg
# Detected dot centers saved for battery (43).jpg
# Detected dot centers saved for battery (431).jpg
# Detected dot centers saved for battery (432).jpg
# Detected dot centers saved for battery (433).jpg
# Detected dot centers saved for battery (434).jpg
# Detected dot centers saved for battery (435).jpg
# Detected dot centers saved for battery (436).jpg
# Detected dot centers saved for battery (437).jpg
# Detected dot centers saved for battery (438).jpg
# Detected dot centers saved for battery (439).jpg
# Detected dot centers saved for battery (44).jpg
# Detected dot centers saved for battery (440).jpg
# Detected dot centers saved for battery (441).jpg
# Detected dot centers saved for battery (442).jpg
# Detected dot centers saved for battery (443).jpg
# Detected dot centers saved for battery (444).jpg
# Detected dot centers saved for battery (445).jpg
# Detected dot centers saved for battery (446).jpg
# Detected dot centers saved for battery (447).jpg
# Detected dot centers saved for battery (448).jpg
# Detected dot centers saved for battery (449).jpg
# Detected dot centers saved for battery (45).jpg
# Detected dot centers saved for battery (450).jpg
# Detected dot centers saved for battery (451).jpg
# Detected dot centers saved for battery (452).jpg
# Detected dot centers saved for battery (453).jpg
# Detected dot centers saved for battery (454).jpg
# Detected dot centers saved for battery (455).jpg
# Detected dot centers saved for battery (456).jpg
# Detected dot centers saved for battery (457).jpg
# Detected dot centers saved for battery (458).jpg
# Detected dot centers saved for battery (459).jpg
# Detected dot centers saved for battery (46).jpg
# Detected dot centers saved for battery (460).jpg
# Detected dot centers saved for battery (461).jpg
# Detected dot centers saved for battery (462).jpg
# Detected dot centers saved for battery (463).jpg
# Detected dot centers saved for battery (464).jpg
# Detected dot centers saved for battery (465).jpg
# Detected dot centers saved for battery (466).jpg
# Detected dot centers saved for battery (467).jpg
# Detected dot centers saved for battery (468).jpg
# Detected dot centers saved for battery (469).jpg
# Detected dot centers saved for battery (47).jpg
# Detected dot centers saved for battery (470).jpg
# Detected dot centers saved for battery (471).jpg
# Detected dot centers saved for battery (472).jpg
# Detected dot centers saved for battery (473).jpg
# Detected dot centers saved for battery (474).jpg
# Detected dot centers saved for battery (475).jpg
# Detected dot centers saved for battery (476).jpg
# Detected dot centers saved for battery (477).jpg
# Detected dot centers saved for battery (478).jpg
# Detected dot centers saved for battery (479).jpg
# Detected dot centers saved for battery (48).jpg
# Detected dot centers saved for battery (480).jpg
# Detected dot centers saved for battery (481).jpg
# Detected dot centers saved for battery (482).jpg
# Detected dot centers saved for battery (483).jpg
# Detected dot centers saved for battery (484).jpg
# Detected dot centers saved for battery (485).jpg
# Detected dot centers saved for battery (486).jpg
# Detected dot centers saved for battery (487).jpg
# Detected dot centers saved for battery (488).jpg
# Detected dot centers saved for battery (489).jpg
# Detected dot centers saved for battery (49).jpg
# Detected dot centers saved for battery (490).jpg
# Detected dot centers saved for battery (491).jpg
# Detected dot centers saved for battery (492).jpg
# Detected dot centers saved for battery (493).jpg
# Detected dot centers saved for battery (494).jpg
# Detected dot centers saved for battery (495).jpg
# Detected dot centers saved for battery (496).jpg
# Detected dot centers saved for battery (498).jpg
# Detected dot centers saved for battery (499).jpg
# Detected dot centers saved for battery (5).jpg
# Detected dot centers saved for battery (50).jpg
# Detected dot centers saved for battery (500).jpg
# Detected dot centers saved for battery (501).jpg
# Detected dot centers saved for battery (502).jpg
# Detected dot centers saved for battery (503).jpg
# Detected dot centers saved for battery (504).jpg
# Detected dot centers saved for battery (505).jpg
# Detected dot centers saved for battery (506).jpg
# Detected dot centers saved for battery (507).jpg
# Detected dot centers saved for battery (508).jpg
# Detected dot centers saved for battery (509).jpg
# Detected dot centers saved for battery (51).jpg
# Detected dot centers saved for battery (510).jpg
# Detected dot centers saved for battery (511).jpg
# Detected dot centers saved for battery (512).jpg
# Detected dot centers saved for battery (513).jpg
# Detected dot centers saved for battery (514).jpg
# Detected dot centers saved for battery (515).jpg
# ...
# Detected dot centers saved for WIN_20240404_18_40_14_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_40_14_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_40_15_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_40_15_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_40_16_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_40_16_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_40_17_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_40_36_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_40_36_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_40_42_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_40_42_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_40_43_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_40_43_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_40_44_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_40_44_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_40_45_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_40_45_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_40_45_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_40_46_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_40_56_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_40_57_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_40_57_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_40_57_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_40_58_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_40_58_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_40_59_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_41_39_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_41_39_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_42_01_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_42_10_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_42_11_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_42_17_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_42_17_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_42_18_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_42_18_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_42_19_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_42_19_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_42_20_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_42_20_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_42_20_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_42_21_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_42_21_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_42_22_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_42_22_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_42_22_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_42_23_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_42_35_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_42_39_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_42_39_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_42_40_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_42_40_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_42_41_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_42_41_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_42_42_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_42_42_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_42_42_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_42_43_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_42_43_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_42_44_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_42_44_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_42_45_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_42_45_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_42_46_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_42_46_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_42_47_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_42_47_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_42_47_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_42_48_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_43_09_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_43_09_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_43_09_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_43_10_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_43_10_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_43_11_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_43_11_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_43_11_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_43_12_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_43_12_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_43_12_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_43_13_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_43_13_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_43_23_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_43_23_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_43_44_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_43_44_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_43_45_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_43_45_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_43_45_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_43_46_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_43_46_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_43_47_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_43_47_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_43_47_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_43_48_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_50_49_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_50_50_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_50_50_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_50_51_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_50_51_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_50_51_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_50_52_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_50_52_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_50_52_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_50_53_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_50_53_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_50_54_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_50_54_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_52_56_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_53_17_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_53_17_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_53_17_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_53_18_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_53_18_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_53_41_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_53_42_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_53_42_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_53_43_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_53_43_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_53_43_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_54_06_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_54_07_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_54_07_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_54_08_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_54_08_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_54_08_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_54_09_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_54_09_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_54_09_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_54_27_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_54_27_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_54_27_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_54_28_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_54_28_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_54_28_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_54_29_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_54_30_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_54_30_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_54_30_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_54_31_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_54_46_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_54_47_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_54_47_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_54_47_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_54_48_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_54_48_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_54_49_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_54_49_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_54_50_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_54_50_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_55_05_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_55_05_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_55_06_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_55_06_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_55_07_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_55_07_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_55_07_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_55_08_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_55_08_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_55_09_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_55_10_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_55_10_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_55_10_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_55_11_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_55_11_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_55_12_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_55_12_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_55_13_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_55_13_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_55_13_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_55_14_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_56_32_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_56_32_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_56_32_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_56_33_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_56_33_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_56_34_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_56_34_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_56_35_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_56_35_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_56_35_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_56_57_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_56_58_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_56_59_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_57_00_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_57_01_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_57_01_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_57_01_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_57_02_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_57_02_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_57_03_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_57_03_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_57_04_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_57_04_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_57_05_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_57_33_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_57_34_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_57_34_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_57_35_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_57_37_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_57_38_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_57_38_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_57_39_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_57_39_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_57_40_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_57_40_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_57_41_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_57_42_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_57_42_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_57_43_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_57_43_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_57_44_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_57_44_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_57_44_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_57_45_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_57_45_Pro.jpg
# Detected dot centers saved for WIN_20240404_18_57_46_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_18_57_46_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_18_57_46_Pro.jpg
# Detected dot centers saved for WIN_20240404_19_10_13_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_19_10_13_Pro.jpg
# Detected dot centers saved for WIN_20240404_19_10_14_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_19_10_14_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_19_10_14_Pro.jpg
# Detected dot centers saved for WIN_20240404_19_10_15_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_19_10_15_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_19_10_15_Pro.jpg
# Detected dot centers saved for WIN_20240404_19_10_16_Pro.jpg
# Detected dot centers saved for WIN_20240404_19_10_20_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_19_10_20_Pro.jpg
# Detected dot centers saved for WIN_20240404_19_10_21_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_19_10_21_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_19_10_21_Pro.jpg
# Detected dot centers saved for WIN_20240404_19_10_22_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_19_10_22_Pro.jpg
# Detected dot centers saved for WIN_20240404_19_10_23_Pro.jpg
# Detected dot centers saved for WIN_20240404_19_10_37_Pro.jpg
# Detected dot centers saved for WIN_20240404_19_10_38_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_19_10_38_Pro.jpg
# Detected dot centers saved for WIN_20240404_19_10_39_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_19_10_39_Pro.jpg
# Detected dot centers saved for WIN_20240404_19_10_40_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_19_10_40_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_19_10_40_Pro.jpg
# Detected dot centers saved for WIN_20240404_19_10_41_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_19_10_41_Pro.jpg
# Detected dot centers saved for WIN_20240404_19_10_42_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_19_10_42_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_19_10_42_Pro.jpg
# Detected dot centers saved for WIN_20240404_19_10_43_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_19_10_43_Pro.jpg
# Detected dot centers saved for WIN_20240404_19_10_44_Pro (2).jpg
# Detected dot centers saved for WIN_20240404_19_10_44_Pro (3).jpg
# Detected dot centers saved for WIN_20240404_19_10_44_Pro.jpg
# Detection process completed.

# %%
Camera matrix (intrinsic parameters):
 [[fx  0 cx]
  [ 0 fy cy]
  [ 0  0  1]]
# Out:
#   Cell In[7], line 1
#     Camera matrix (intrinsic parameters):
#            ^
# SyntaxError: invalid syntax
