# %%
import cv2
import numpy as np
from ultralytics import YOLO

# Load your trained YOLOv8 model
model = YOLO('best.pt')  # Replace with 'yolov8n.pt' if needed

# Load corner points calibration data
corner_points = np.load('corner_points.npz')['corner_points']
tl, tr, bl, br = corner_points[:4]

# Define class names (must match your trained model)
class_names = ['AA', 'D type', '9v']

# Initialize camera (adjust camera_index as needed)
camera_index = 1  # Example: change this to match your external camera index
cap = cv2.VideoCapture(camera_index)

if not cap.isOpened():
    print(f"Error: Could not open camera with index {camera_index}")
    exit()

# Function to map detected position to normalized grid coordinates
def map_to_grid(x, y, tl, tr, bl, br):
    # Compute vectors for mapping to normalized grid coordinates
    v1 = np.array([tr[0] - tl[0], tr[1] - tl[1]])
    v2 = np.array([bl[0] - tl[0], bl[1] - tl[1]])
    vp = np.array([x - tl[0], y - tl[1]])

    # Calculate normalized grid coordinates (u, v)
    u = np.dot(vp, v1) / np.dot(v1, v1)
    v = np.dot(vp, v2) / np.dot(v2, v2)

    return u, v

# Function to convert grid coordinates to robot coordinates
def grid_to_robot(u, v, tl, tr, bl, br):
    # Calculate the robot coordinates (X, Y, Z) from the normalized grid coordinates (u, v)
    x_robot = tl[0] + u * (tr[0] - tl[0]) + v * (bl[0] - tl[0])
    y_robot = tl[1] + u * (tr[1] - tl[1]) + v * (bl[1] - tl[1])
    z_robot = tl[2] + u * (tr[2] - tl[2]) + v * (bl[2] - tl[2])  # Adjust for height if necessary

    return x_robot, y_robot, z_robot

try:
    while True:
        ret, frame = cap.read()  # Capture frame-by-frame

        if not ret:
            print("Error: Failed to capture image")
            break

        # Perform inference
        results = model(frame)[0]  # Get the first result

        # Iterate through the detected objects
        detections = []
        for result in results.boxes.data:
            x1, y1, x2, y2, confidence, class_id = result.tolist()

            # Calculate center coordinates of the bounding box
            x_center = (x1 + x2) / 2
            y_center = (y1 + y2) / 2

            # Map the detected position to the grid coordinates
            u, v = map_to_grid(x_center, y_center, tl, tr, bl, br)

            # Convert grid coordinates to robot coordinates
            x_robot, y_robot, z_robot = grid_to_robot(u, v, tl, tr, bl, br)

            # Save detection information (battery type and coordinates)
            detections.append({
                'battery_type': class_names[int(class_id)],
                'robot_coordinates': (x_robot, y_robot, z_robot)
            })

            # Draw bounding box and label
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (255, 0, 0), 2)
            label = f'{class_names[int(class_id)]} {confidence:.2f}'
            cv2.putText(frame, label, (int(x1), int(y1 - 10)),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

        # Display the frame with detections
        cv2.imshow('Battery Detection', frame)

        # Print or log the detected battery information
        for detection in detections:
            print(f"Detected {detection['battery_type']} at robot coordinates {detection['robot_coordinates']}")

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

except KeyboardInterrupt:
    print("Detection stopped by user.")
finally:
    # Release the capture and close all windows
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 D type, 490.9ms
# Speed: 15.6ms preprocess, 490.9ms inference, 45.8ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (334.35654897315, 226.9064925997726, 149.03160248598783)
#
# 0: 480x640 1 D type, 324.9ms
# Speed: 7.9ms preprocess, 324.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.6454114370375, 226.94887613135924, 149.00014018618717)
#
# 0: 480x640 1 D type, 294.5ms
# Speed: 6.1ms preprocess, 294.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.63142898159265, 227.10101809266308, 149.00138138567215)
#
# 0: 480x640 1 D type, 275.9ms
# Speed: 3.7ms preprocess, 275.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.6162907570555, 227.01336351278712, 148.9996231384056)
#
# 0: 480x640 1 D type, 282.5ms
# Speed: 6.1ms preprocess, 282.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.7403932169367, 226.86825399355342, 149.00342100198262)
#
# 0: 480x640 1 D type, 285.4ms
# Speed: 4.0ms preprocess, 285.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.59889819664704, 227.1100557353596, 149.00002940704584)
#
# 0: 480x640 1 D type, 255.3ms
# Speed: 3.6ms preprocess, 255.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.8211169323956, 227.23830089096055, 149.01159997617353)
#
# 0: 480x640 1 D type, 233.9ms
# Speed: 3.4ms preprocess, 233.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.723402364456, 227.09184818838284, 149.00540515669937)
#
# 0: 480x640 1 D type, 242.0ms
# Speed: 3.8ms preprocess, 242.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.7025086979208, 226.87298667569448, 149.00177532576416)
#
# 0: 480x640 1 D type, 219.2ms
# Speed: 3.1ms preprocess, 219.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.37352352526136, 226.99701463311067, 148.9885037814613)
#
# 0: 480x640 1 AA, 1 D type, 228.0ms
# Speed: 2.6ms preprocess, 228.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.67619547878803, 227.01462135831167, 149.0023328012687)
# Detected AA at robot coordinates (334.622561572122, 227.61470395747156, 149.05227134646677)
#
# 0: 480x640 1 D type, 211.2ms
# Speed: 3.5ms preprocess, 211.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (334.0679004185413, 227.17383119574217, 149.02190657939056)
#
# 0: 480x640 1 D type, 216.1ms
# Speed: 3.5ms preprocess, 216.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.5721938208184, 227.10884196253363, 148.9988134643432)
#
# 0: 480x640 1 D type, 214.4ms
# Speed: 4.4ms preprocess, 214.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (334.70029950131845, 226.9547642881747, 149.04765592518632)
#
# 0: 480x640 1 D type, 212.8ms
# Speed: 3.1ms preprocess, 212.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (334.46702850123495, 227.08493978858, 149.0387646679826)
#
# 0: 480x640 1 D type, 267.9ms
# Speed: 2.3ms preprocess, 267.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (334.30277534406935, 227.17439168975045, 149.0324769181427)
#
# 0: 480x640 1 D type, 215.2ms
# Speed: 3.0ms preprocess, 215.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.5067446207142, 227.05266171472778, 148.9951793594205)
#
# 0: 480x640 1 D type, 202.1ms
# Speed: 2.8ms preprocess, 202.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.4389054711304, 227.29222455879102, 148.99507290200057)
#
# 0: 480x640 1 AA, 1 D type, 206.3ms
# Speed: 4.0ms preprocess, 206.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (334.2040670031627, 226.993555456322, 149.0258147777551)
# Detected AA at robot coordinates (335.07256629356266, 227.57663624259473, 149.07204230189777)
#
# 0: 480x640 1 D type, 201.2ms
# Speed: 3.0ms preprocess, 201.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.2736173768335, 226.958335132377, 148.98353509362525)
#
# 0: 480x640 1 D type, 199.5ms
# Speed: 3.1ms preprocess, 199.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.1176100657838, 226.934264785797, 148.97622283687795)
#
# 0: 480x640 1 D type, 198.7ms
# Speed: 4.0ms preprocess, 198.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.403841454122, 226.90587212877912, 148.98874704302233)
#
# 0: 480x640 1 D type, 206.1ms
# Speed: 3.0ms preprocess, 206.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (334.50107858696515, 227.01602740467996, 149.03944902468209)
#
# 0: 480x640 1 D type, 198.6ms
# Speed: 3.0ms preprocess, 198.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.95774782803096, 226.93478827896908, 149.01401428715909)
#
# 0: 480x640 1 D type, 203.3ms
# Speed: 3.5ms preprocess, 203.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.5574993708548, 226.98786133095928, 148.99666554759202)
#
# 0: 480x640 1 D type, 201.7ms
# Speed: 3.0ms preprocess, 201.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.0153992544241, 227.17007171143516, 148.97452435535573)
#
# 0: 480x640 1 D type, 200.4ms
# Speed: 4.0ms preprocess, 200.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (334.2375161223872, 227.20714630053837, 149.0299445029058)
#
# 0: 480x640 1 D type, 204.7ms
# Speed: 4.0ms preprocess, 204.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.58832275349806, 226.91179713348532, 148.9971168772836)
#
# 0: 480x640 1 D type, 200.0ms
# Speed: 4.8ms preprocess, 200.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.1492312815021, 227.0909612171911, 148.97957103310097)
#
# 0: 480x640 1 D type, 203.9ms
# Speed: 4.1ms preprocess, 203.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.7048128647168, 226.85861921599687, 149.00170235711565)
#
# 0: 480x640 1 D type, 206.9ms
# Speed: 5.0ms preprocess, 206.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (334.6026286503499, 227.0245586968428, 149.0441210796428)
#
# 0: 480x640 1 D type, 210.6ms
# Speed: 4.0ms preprocess, 210.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.57597013529517, 226.98114444716015, 148.9974137054869)
#
# 0: 480x640 1 D type, 207.5ms
# Speed: 4.4ms preprocess, 207.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (334.70563046307063, 227.0386339015205, 149.0489265698834)
#
# 0: 480x640 1 D type, 203.1ms
# Speed: 4.5ms preprocess, 203.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (334.08795751712324, 226.8488604347133, 149.0188142553705)
#
# 0: 480x640 1 D type, 200.5ms
# Speed: 3.1ms preprocess, 200.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.33368608203455, 227.13671427991935, 148.9884292233366)
#
# 0: 480x640 1 D type, 201.7ms
# Speed: 4.0ms preprocess, 201.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.8159905844899, 226.84311624601355, 149.00651199601384)
#
# 0: 480x640 1 D type, 198.4ms
# Speed: 3.0ms preprocess, 198.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.6840818986128, 226.99963065934844, 149.00250323268958)
#
# 0: 480x640 1 D type, 203.8ms
# Speed: 4.9ms preprocess, 203.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.3379518405486, 227.03831717714078, 148.98741162400975)
#
# 0: 480x640 1 D type, 206.2ms
# Speed: 4.4ms preprocess, 206.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (334.1322482276355, 226.9977534278264, 149.0226363432132)
#
# 0: 480x640 1 D type, 222.7ms
# Speed: 3.2ms preprocess, 222.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.57669559207943, 226.84400670126425, 148.99576070008703)
#
# 0: 480x640 1 D type, 203.4ms
# Speed: 4.3ms preprocess, 203.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (334.16232168329236, 227.03181700942986, 149.02440758395588)
#
# 0: 480x640 1 D type, 201.0ms
# Speed: 2.2ms preprocess, 201.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (334.2712168907418, 226.97968323425866, 149.0286643187253)
#
# 0: 480x640 1 D type, 206.3ms
# Speed: 4.0ms preprocess, 206.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.28997534011575, 227.1131978409858, 148.9861742890842)
#
# 0: 480x640 1 D type, 200.8ms
# Speed: 3.2ms preprocess, 200.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.75257447551576, 226.89901058600555, 149.00434689704238)
#
# 0: 480x640 1 D type, 203.5ms
# Speed: 3.3ms preprocess, 203.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.8878431122421, 227.04237762128457, 149.01219277513852)
#
# 0: 480x640 1 D type, 203.7ms
# Speed: 2.1ms preprocess, 203.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.4419053864999, 226.99637657929702, 148.99157139835356)
#
# 0: 480x640 1 D type, 203.8ms
# Speed: 4.0ms preprocess, 203.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (334.2558827261262, 227.02292680850755, 149.02850619763203)
#
# 0: 480x640 1 D type, 201.6ms
# Speed: 3.1ms preprocess, 201.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.69191106931294, 226.8605163667388, 149.00114542051773)
#
# 0: 480x640 1 D type, 198.9ms
# Speed: 4.4ms preprocess, 198.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.985812014327, 226.97034096204374, 149.01571346477783)
#
# 0: 480x640 1 D type, 260.2ms
# Speed: 3.4ms preprocess, 260.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.7985091083659, 227.19127483483928, 149.01000517197355)
#
# 0: 480x640 1 D type, 200.5ms
# Speed: 2.9ms preprocess, 200.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.2751670691121, 227.08157838126456, 148.98511963874523)
#
# 0: 480x640 1 D type, 200.0ms
# Speed: 4.3ms preprocess, 200.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.2531249974922, 226.94336140516216, 148.98242940324621)
#
# 0: 480x640 1 AA, 1 D type, 198.8ms
# Speed: 4.1ms preprocess, 198.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (334.0968664238005, 226.79056559103347, 149.0184983987417)
# Detected AA at robot coordinates (335.06099229520964, 227.34248337210482, 149.06864366686406)
#
# 0: 480x640 1 AA, 1 D type, 200.0ms
# Speed: 3.0ms preprocess, 200.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (334.4369326178454, 226.96667242443846, 149.0359574252718)
# Detected AA at robot coordinates (335.22267015534715, 227.62517991721276, 149.07938986691602)
#
# 0: 480x640 1 D type, 214.0ms
# Speed: 3.0ms preprocess, 214.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.98364344030324, 226.82510634669293, 149.01383077805218)
#
# 0: 480x640 1 D type, 205.9ms
# Speed: 4.3ms preprocess, 205.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (334.1706009220995, 226.871004671308, 149.02280331133196)
#
# 0: 480x640 1 D type, 209.1ms
# Speed: 3.3ms preprocess, 209.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.9528985679932, 227.0030911604941, 149.01463573961863)
#
# 0: 480x640 1 D type, 209.2ms
# Speed: 3.3ms preprocess, 209.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.8321587561243, 227.07298039110879, 149.01006453801085)
#
# 0: 480x640 1 D type, 214.0ms
# Speed: 3.8ms preprocess, 214.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (334.30749925853263, 227.10505074331718, 149.03183706888726)
#
# 0: 480x640 1 D type, 202.4ms
# Speed: 3.0ms preprocess, 202.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.0423590691619, 227.1845013009862, 148.97591422897105)
#
# 0: 480x640 1 D type, 201.3ms
# Speed: 2.2ms preprocess, 201.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (333.85845949900215, 227.05272231297994, 149.01099840551646)
#
# 0: 480x640 1 D type, 201.5ms
# Speed: 4.0ms preprocess, 201.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (336.0836213323739, 226.86486867695763, 149.10876557341675)
#
# 0: 480x640 1 D type, 203.6ms
# Speed: 4.0ms preprocess, 203.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (336.56723151574914, 226.63670890423614, 149.1277114051379)
#
# 0: 480x640 (no detections), 203.4ms
# Speed: 4.0ms preprocess, 203.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 204.2ms
# Speed: 3.1ms preprocess, 204.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 200.5ms
# Speed: 4.0ms preprocess, 200.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 200.5ms
# Speed: 4.1ms preprocess, 200.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 D types, 203.6ms
# Speed: 3.0ms preprocess, 203.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (188.21777009907117, 33.37246761762529, 140.08021303812643)
# Detected D type at robot coordinates (210.29905205399513, 33.32479599508839, 141.07272800313024)
#
# 0: 480x640 1 D type, 202.8ms
# Speed: 3.5ms preprocess, 202.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (184.47563323982422, 36.88985026083319, 139.9551452479972)
#
# 0: 480x640 1 D type, 203.1ms
# Speed: 2.3ms preprocess, 203.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (180.70781783107577, 38.156246425991206, 139.80125450368047)
#
# 0: 480x640 1 D type, 201.0ms
# Speed: 3.3ms preprocess, 201.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (180.54191294741355, 38.16734057523098, 139.79392933116804)
#
# 0: 480x640 (no detections), 197.9ms
# Speed: 3.6ms preprocess, 197.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 D type, 196.5ms
# Speed: 3.0ms preprocess, 196.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (189.58673231098868, 38.89221351424073, 140.2096279402146)
#
# 0: 480x640 1 D type, 202.9ms
# Speed: 3.5ms preprocess, 202.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (181.61428934175052, 38.5116640318197, 139.84639149156786)
#
# 0: 480x640 2 D types, 196.9ms
# Speed: 3.9ms preprocess, 196.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (261.988485902991, 219.03888769681666, 145.68015946502646)
# Detected D type at robot coordinates (182.0027925883291, 38.902979015547416, 139.86867420150205)
#
# 0: 480x640 1 D type, 201.3ms
# Speed: 3.2ms preprocess, 201.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (267.6170137491988, 217.7839161243591, 145.91787577803996)
#
# 0: 480x640 2 D types, 206.8ms
# Speed: 3.0ms preprocess, 206.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (267.9697102679376, 219.964211994564, 145.96053739958927)
# Detected D type at robot coordinates (181.5297212431543, 38.92742011633731, 139.84769833768317)
#
# 0: 480x640 1 D type, 207.3ms
# Speed: 3.0ms preprocess, 207.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (181.52343864474278, 38.41760477784301, 139.84114936884183)
#
# 0: 480x640 1 D type, 202.5ms
# Speed: 3.0ms preprocess, 202.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (181.15714013969068, 38.87140434861169, 139.83025306296122)
#
# 0: 480x640 (no detections), 198.8ms
# Speed: 3.0ms preprocess, 198.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 D type, 199.6ms
# Speed: 4.1ms preprocess, 199.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (205.54189186049194, 8.431558120972582, 140.55279977304286)
#
# 0: 480x640 (no detections), 208.3ms
# Speed: 3.0ms preprocess, 208.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 203.3ms
# Speed: 4.2ms preprocess, 203.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 202.7ms
# Speed: 4.4ms preprocess, 202.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 204.1ms
# Speed: 3.0ms preprocess, 204.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 203.2ms
# Speed: 3.0ms preprocess, 203.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 205.4ms
# Speed: 3.0ms preprocess, 205.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 201.9ms
# Speed: 4.1ms preprocess, 201.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 203.0ms
# Speed: 4.0ms preprocess, 203.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 D type, 1 9v, 200.5ms
# Speed: 3.0ms preprocess, 200.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (235.70893780659225, 149.0542878188959, 143.63802464208698)
# Detected D type at robot coordinates (235.69248183029242, 148.3961100088473, 143.62919452604513)
#
# 0: 480x640 1 9v, 204.3ms
# Speed: 3.5ms preprocess, 204.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (235.8971600653814, 148.6803504115648, 143.64189363511363)
#
# 0: 480x640 1 9v, 214.3ms
# Speed: 3.0ms preprocess, 214.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (235.8123149488589, 148.50250321510657, 143.63589173010715)
#
# 0: 480x640 1 D type, 1 9v, 213.8ms
# Speed: 7.0ms preprocess, 213.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (235.45996521199277, 148.54288295675065, 143.62054120501767)
# Detected D type at robot coordinates (235.53128749852937, 148.15048492322654, 143.61892573751985)
#
# 0: 480x640 1 D type, 1 9v, 217.8ms
# Speed: 3.1ms preprocess, 217.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (235.53000011950076, 149.0885518531845, 143.63039811536223)
# Detected D type at robot coordinates (235.3986490982632, 148.50545104377588, 143.61732343048115)
#
# 0: 480x640 1 D type, 1 9v, 216.1ms
# Speed: 3.4ms preprocess, 216.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (235.43519133570095, 148.80449143809238, 143.62264257363498)
# Detected D type at robot coordinates (235.45128209777414, 148.34475242456872, 143.6177153565158)
#
# 0: 480x640 1 D type, 1 9v, 209.7ms
# Speed: 3.2ms preprocess, 209.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (235.37097811103916, 148.52181352847862, 143.6162800537279)
# Detected 9v at robot coordinates (235.40672302723272, 149.0124079752978, 143.62391782983642)
#
# 0: 480x640 1 D type, 1 9v, 205.2ms
# Speed: 3.3ms preprocess, 205.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (235.43627520667434, 148.78057890968725, 143.6223973989489)
# Detected D type at robot coordinates (235.43402501287818, 148.30108521040262, 143.61640248596657)
#
# 0: 480x640 1 D type, 1 9v, 208.2ms
# Speed: 3.0ms preprocess, 208.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (235.50219883308387, 148.89023489948926, 143.6267101397587)
# Detected D type at robot coordinates (235.4587541626887, 148.34828202573547, 143.6180947952307)
#
# 0: 480x640 1 D type, 1 9v, 208.9ms
# Speed: 4.1ms preprocess, 208.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (235.42540719084627, 148.9285075748515, 143.62372688183376)
# Detected D type at robot coordinates (235.2665335886382, 148.37491224383993, 143.60977704223492)
#
# 0: 480x640 1 D type, 1 9v, 268.8ms
# Speed: 4.0ms preprocess, 268.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (235.42231285677627, 148.3655018135085, 143.61666751284068)
# Detected 9v at robot coordinates (235.44193053770766, 148.9910183492539, 143.62523836885057)
#
# 0: 480x640 1 D type, 1 9v, 207.2ms
# Speed: 3.1ms preprocess, 207.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (235.5825264244006, 148.89414775884234, 143.63037095098423)
# Detected D type at robot coordinates (235.4977770516171, 148.36095296253725, 143.62000558648936)
#
# 0: 480x640 1 D type, 1 9v, 205.6ms
# Speed: 2.0ms preprocess, 205.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (235.45582363493423, 148.78172806233022, 143.62329071016285)
# Detected D type at robot coordinates (235.37865362687262, 148.16064159838655, 143.61218590293691)
#
# 0: 480x640 1 D type, 1 9v, 201.7ms
# Speed: 4.1ms preprocess, 201.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (235.33436209916033, 148.8308769064925, 143.6184321181031)
# Detected D type at robot coordinates (235.3259853574861, 148.3053783295138, 143.61159619462737)
#
# 0: 480x640 1 D type, 1 9v, 203.7ms
# Speed: 2.7ms preprocess, 203.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (235.661001416622, 149.0358013735924, 143.63564148653492)
# Detected D type at robot coordinates (235.56736394084652, 148.41323598020426, 143.6237778801738)
#
# 0: 480x640 1 D type, 1 9v, 211.3ms
# Speed: 3.0ms preprocess, 211.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (235.474741024435, 148.9112828252317, 143.62573394190343)
# Detected D type at robot coordinates (235.46272697691353, 148.34531893785413, 143.61823705081636)
#
# 0: 480x640 1 D type, 1 9v, 204.6ms
# Speed: 4.1ms preprocess, 204.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected D type at robot coordinates (235.5591832427976, 148.393101446467, 143.62316247081537)
# Detected 9v at robot coordinates (235.67919529601556, 148.9175152213801, 143.63500583461885)
#
# 0: 480x640 1 D type, 1 9v, 200.0ms
# Speed: 4.1ms preprocess, 200.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (235.8997299749044, 149.02948807236655, 143.6463006521364)
# Detected D type at robot coordinates (235.7757174386834, 148.4559173671923, 143.63367315360406)
#
# 0: 480x640 1 D type, 1 9v, 199.2ms
# Speed: 3.2ms preprocess, 199.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (235.82842357279696, 148.38580129769727, 143.635181766943)
# Detected D type at robot coordinates (235.48689133304197, 148.31049240842518, 143.6188957662355)
#
# 0: 480x640 1 D type, 1 9v, 203.3ms
# Speed: 3.1ms preprocess, 203.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (235.46444567053788, 149.01358261325925, 143.62652833144182)
# Detected D type at robot coordinates (235.39621752940815, 148.49885110127138, 143.6171329478045)
#
# 0: 480x640 1 D type, 1 9v, 212.6ms
# Speed: 3.0ms preprocess, 212.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates
6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (250.02934151723804, 204.90502169823282, 144.96857267775246)
#
# 0: 480x640 1 9v, 245.0ms
# Speed: 4.2ms preprocess, 245.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (250.0202230201354, 204.8681861324847, 144.9677098098533)
#
# 0: 480x640 1 9v, 284.2ms
# Speed: 2.5ms preprocess, 284.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (249.93999843848235, 204.92091425280756, 144.9647498357437)
#
# 0: 480x640 1 9v, 221.8ms
# Speed: 3.0ms preprocess, 221.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (249.54555806893165, 204.9820476206568, 144.9477613872834)
#
# 0: 480x640 1 9v, 219.3ms
# Speed: 3.0ms preprocess, 219.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (249.62049690934595, 204.76333691457882, 144.9484434564477)
#
# 0: 480x640 1 9v, 245.5ms
# Speed: 4.0ms preprocess, 245.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (250.10543935620058, 204.88856837531534, 144.97179292524035)
#
# 0: 480x640 1 9v, 270.0ms
# Speed: 4.6ms preprocess, 270.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (249.96958038016237, 205.0310617631859, 144.96743415861343)
#
# 0: 480x640 1 9v, 238.3ms
# Speed: 4.1ms preprocess, 238.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (249.77977886367484, 204.99286064574977, 144.95842832593303)
#
# 0: 480x640 1 9v, 237.1ms
# Speed: 3.0ms preprocess, 237.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (249.95191968305818, 204.98038901174658, 144.9660170269229)
#
# 0: 480x640 1 9v, 269.3ms
# Speed: 4.5ms preprocess, 269.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (250.10771072342533, 204.79636044705455, 144.97076170301457)
#
# 0: 480x640 1 9v, 244.7ms
# Speed: 5.0ms preprocess, 244.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (249.91812470482682, 204.9997535531978, 144.96473512485636)
#
# 0: 480x640 1 9v, 216.3ms
# Speed: 2.8ms preprocess, 216.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (249.79383459863868, 204.9313470140903, 144.95830438297529)
#
# 0: 480x640 1 9v, 231.4ms
# Speed: 2.5ms preprocess, 231.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (249.66417030453601, 204.87145370224175, 144.95173657872976)
#
# 0: 480x640 1 9v, 270.1ms
# Speed: 3.5ms preprocess, 270.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 9v at robot coordinates (249.99870418598232, 204.8904431272772, 144.96701557741076)

# %%
import time

def move_to_position(x, y, z):
    # Simulate the robot's movement in RC software
    print(f"Moving to position: X: {x}, Y: {y}, Z: {z}")
    time.sleep(3)  # Simulate delay

def magnet_control(state):
    # Simulate magnet control in RC software
    if state == "ON":
        print("Magnet ON (Simulation)")
    else:
        print("Magnet OFF (Simulation)")
    time.sleep(3)  # Simulate delay

def main_simulation():
    # Corner points simulation for battery sorting
    aa_drop_position = (100, 200, 300)  # Example drop position for AA
    d_drop_position = (150, 250, 350)   # Example drop position for D
    v9_drop_position = (200, 300, 400)  # Example drop position for 9V
    
    # Simulate detecting a battery
    print("Battery detected: AA")
    
    # Move to the battery pickup position (simulate)
    move_to_position(50, 50, 50)
    
    # Activate the electromagnet (simulate)
    magnet_control("ON")
    
    # Move to the AA drop position (simulate)
    move_to_position(*aa_drop_position)
    
    # Deactivate the electromagnet (simulate)
    magnet_control("OFF")

if __name__ == "__main__":
    main_simulation()
# Out:
# Battery detected: AA
# Moving to position: X: 50, Y: 50, Z: 50
# Magnet ON (Simulation)
# Moving to position: X: 100, Y: 200, Z: 300
# Magnet OFF (Simulation)

# %%
import cv2
import socket
import time
import torch

# Load your trained YOLOv8 model
model = YOLO('best.pt')  # Replace with 'yolov8n.pt' if needed

# Define class names (must match your trained model)
class_names = ['AA', 'D type', '9v']

# Setup TCP connection parameters (change according to mode)
HOST = '127.0.0.1'  # Localhost or IP of real robot
PORT = 2000         # Port number for TCP/IP communication

# Define function to send commands to robot (simulation or real)
def send_command(command):
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        s.connect((HOST, PORT))
        s.sendall(command.encode())
        data = s.recv(1024)
        print(f'Received: {data.decode()}')

# Define function to capture frames and detect batteries in real time
def detect_batteries():
    cap = cv2.VideoCapture(1)  # Open the default camera
    
    while True:
        ret, frame = cap.read()  # Capture frame-by-frame
        if not ret:
            break

        # Perform YOLO detection
        results = model(frame)
        results.render()  # Render the results on the frame

        # Display the resulting frame with detections
        cv2.imshow('Battery Detection', frame)

        # Extract battery type and coordinates
        for result in results.xyxy[0]:
            x1, y1, x2, y2, confidence, class_id = result
            battery_type = int(class_id)
            battery_coordinates = (x1.item(), y1.item(), x2.item(), y2.item())
            
            if battery_type == 0:  # Assuming 0 is AA type
                move_robot_to_battery(battery_coordinates, 'AA')
            elif battery_type == 1:  # Assuming 1 is 9V type
                move_robot_to_battery(battery_coordinates, '9V')
            elif battery_type == 2:  # Assuming 2 is D type
                move_robot_to_battery(battery_coordinates, 'D')

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    cap.release()
    cv2.destroyAllWindows()

# Define function to move the robot to the battery position based on type
def move_robot_to_battery(coords, battery_type):
    x1, y1, x2, y2 = coords
    # Calculate battery center point
    x = (x1 + x2) / 2
    y = (y1 + y2) / 2

    # Move robot to the detected battery's position
    send_command(f'MOVE X={x}, Y={y}')
    time.sleep(3)  # Wait for robot to reach

    # Adjust height based on battery type
    if battery_type == 'AA':
        send_command('MOVE Z=1')  # Move 1 cm above
    elif battery_type == '9V':
        send_command('MOVE Z=2')  # Move 2 cm above
    elif battery_type == 'D':
        send_command('MOVE Z=4')  # Move 4 cm above
    
    time.sleep(3)  # Delay for smoothness

    # Activate electromagnet to pick the battery
    send_command('MAGNET ON')
    time.sleep(3)  # Wait to pick

    # Move to drop location based on battery type
    if battery_type == 'AA':
        send_command('MOVE X=DROP_AA_X, Y=DROP_AA_Y')
    elif battery_type == '9V':
        send_command('MOVE X=DROP_9V_X, Y=DROP_9V_Y')
    elif battery_type == 'D':
        send_command('MOVE X=DROP_D_X, Y=DROP_D_Y')

    time.sleep(3)  # Wait to reach the drop point

    # Deactivate electromagnet to drop the battery
    send_command('MAGNET OFF')
    time.sleep(3)  # Wait for the battery to detach

# Main function to run both detection and robot control
def main():
    print("Starting battery detection and robot control...")
    
    # Start the battery detection and robot movement
    detect_batteries()

if __name__ == '__main__':
    main()
# Out:
# Starting battery detection and robot control...
#
# 0: 480x640 1 D type, 1 9v, 355.4ms
# Speed: 6.5ms preprocess, 355.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 107
#     104     detect_batteries()
#     106 if __name__ == '__main__':
# --> 107     main()
#
# Cell In[5], line 104, in main()
#     101 print("Starting battery detection and robot control...")
#     103 # Start the battery detection and robot movement
# --> 104 detect_batteries()
#
# Cell In[5], line 35, in detect_batteries()
#      33 # Perform YOLO detection
#      34 results = model(frame)
# ---> 35 results.render()  # Render the results on the frame
#      37 # Display the resulting frame with detections
#      38 cv2.imshow('Battery Detection', frame)
#
# AttributeError: 'list' object has no attribute 'render'
